# %%
import pandas as pd

# %%
data = pd.read_excel("data.xlsx")

# %%
data.to_csv("data.csv")

# %%
data
# Out:
#         ID          Name                               Sequence  Tiny  Small  \
# 0   AbAMP1    Aurein 1.2                          GLFDIIKKIAESF   3.0    4.0
# 1   AbAMP2         CAMEL                        KWKLFKKIGAVLKVL   2.0    4.0
# 2   AbAMP3  Citropin 1.1                       GLFDVIKKVASVIGGL   5.0    9.0
# 3   AbAMP4         LL-37  LLGDFFRKSKEKIGKEFKRIVQRIKDFLRNLVPRTES   5.0   11.0
# 4   AbAMP5      Omiganan                           ILRWPWWPWRRK   0.0    2.0
# ..     ...           ...                                    ...   ...    ...
# 74     NaN           NaN                                    NaN   NaN    NaN
# 75     NaN           NaN                                    NaN   NaN    NaN
# 76     NaN           NaN                                    NaN   NaN    NaN
# 77     NaN           NaN                                    NaN   NaN    NaN
# 78     NaN           NaN                                    NaN   NaN    NaN
#
# ...
